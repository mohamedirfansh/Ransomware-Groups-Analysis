# %%
# Importing modules

import socks
import socket
import requests
import codecs
from bs4 import BeautifulSoup

# %% [markdown]
# ## Data Extraction from HTML

# %%
# Extract useful data from each post
dates = []
views = []
name = []
desc = []
def extract_data_from_post(page):
    file = codecs.open(f"../raw-html/snatch{page}.html", "r", "utf-8")
    index = file.read()
    soup = BeautifulSoup(index, 'lxml')
    
    post_dates_tag = soup.find_all("div", {"class": "a-b-h-time"})
    post_dates = [tag.text.strip() for tag in post_dates_tag]
    dates.extend(post_dates)
    
    post_views_tag = soup.find_all("p", {"class": "a-b-h-v-c-views"})
    post_views = [tag.text.strip() for tag in post_views_tag]
    views.extend(post_views)
    
    post_company_tag = soup.find_all("div", {"class": "a-b-n-name"})
    post_company = [tag.text.strip() for tag in post_company_tag]
    name.extend(post_company)
    
    post_desc_tag = soup.find_all("div", {"class": "a-b-text"})
    post_desc = [tag.text.strip() for tag in post_desc_tag]
    desc.extend(post_desc)

# %%
for i in range(1, 6):
    extract_data_from_post(i)
    
print(dates)
print(views)
print(name)
print(desc)

# %%
print(len(dates) == len(views) == len(name) == len(desc))
# Out:
# True

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(columns=['Company Name', 'Location', 'Industry', 'Description', 'Post Date', 'Post Views'])
df['Company Name'] = name
df['Description'] = desc
df['Post Date'] = dates
df['Post Views'] = views

df
# Out:
#                              Company Name Location Industry  \
# 0                    Stratford University      NaN      NaN
# 1                  The Execu|Search Group      NaN      NaN
# 2                            Lootah Group      NaN      NaN
# 3                                    LAVA      NaN      NaN
# 4                      Hall Cross Academy      NaN      NaN
# 5   Atlantic Dialysis Management Services      NaN      NaN
# 6                                 HEMERIA      NaN      NaN
# 7                                    Apex      NaN      NaN
# 8                        Warren Resources      NaN      NaN
# 9                                   Xtera      NaN      NaN
# 10                              Mab Group      NaN      NaN
# 11                             McDonald's      NaN      NaN
# 12                     Medical Pharmacies      NaN      NaN
# 13                             APG Neuros      NaN      NaN
# 14                      Thomson Broadbent      NaN      NaN
# 15                                 TUI UK      NaN      NaN
# 16                          InTown Suites      NaN      NaN
# 17                                  Leuze      NaN      NaN
# 18                            Yip in Tsoi      NaN      NaN
# 19                          Hanon Systems      NaN      NaN
# 20                 Overseas Travel Agency      NaN      NaN
# 21                  Volvo Car Corporation      NaN      NaN
# 22                               Arbitech      NaN      NaN
# 23                Skyxe Saskatoon Airport      NaN      NaN
# 24                     Private company #2      NaN      NaN
# 25                      Cadence Aerospace      NaN      NaN
# 26                                 HAPOLO      NaN      NaN
# 27                           ABC Seamless      NaN      NaN
# 28                     Amtech Corporation      NaN      NaN
# 29           Premium Transportation Group      NaN      NaN
# 30               QRS Healthcare Solutions      NaN      NaN
# 31                        CareFirst CHPDC      NaN      NaN
# 32                             Fittingbox      NaN      NaN
# 33                        Private Company      NaN      NaN
# 31  CareFirst BlueCross BlueShield Community Healt...  Jan 23, 2022 10:02 PM
# 32  Today, Fittingbox employs more than 80 people ...  Jan 20, 2022 11:09 PM
# 33  SSN_1.csv; PATIENTCONTACTS_VIEW.csv; IB_Appoin...  Jan 16, 2022 09:58 PM
# 34  TaxNetUSA was founded in 1994 and has since be...  Jan 14, 2022 05:06 AM
# 35  Altrux Medical was established in 2006 and is ...  Jan 14, 2022 01:29 AM
# 36  Led by Phillip A. Bock, the attorneys at Bock ...   Jan 8, 2022 09:09 PM
# 37  When Paul Stephens founded Landmark Builders i...   Jan 7, 2022 08:52 PM
# 38  Public Label’s cultural movements’ strategic a...   Jan 6, 2022 08:27 PM
# 39  On our organic farms in the Cotswolds and Staf...  Dec 30, 2021 07:16 PM
# 40  Founded in Kyoto, Japan, in 1893, Ishida is no...  Dec 30, 2021 06:14 AM
#
#    Post Views
# 0       67095
# 1      128906
# 2      166360
# 3      264558
# 4      160810
# 5      126911
# 6      192516
# 7      125600
# 8      195431
# 9      247429
# 10     276942
# 11     176149
# 12     234424
# 13     233405
# 14     222602
# 15     189660
# 16     157351
# 17     159167
# 18      92487
# 19     150285
# 20      74783
# 21     153064
# 22     147025
# 23     157151
# 24      61568
# 25     140427
# 26      72247
# 27     108124
# 28     113907
# 29      78444
# 30      91410
# 31      95852
# 32      83192
# 33      52161
# 34      47630
# 35      68831
# 36      87862
# 37      87324
# 38      95687
# 39      92826
# 40     118541

# %% [markdown]
# ### Drop posts not in 2022

# %%
df = df.drop([39, 40])
df
# Out:
#                              Company Name Location Industry  \
# 0                    Stratford University      NaN      NaN
# 1                  The Execu|Search Group      NaN      NaN
# 2                            Lootah Group      NaN      NaN
# 3                                    LAVA      NaN      NaN
# 4                      Hall Cross Academy      NaN      NaN
# 5   Atlantic Dialysis Management Services      NaN      NaN
# 6                                 HEMERIA      NaN      NaN
# 7                                    Apex      NaN      NaN
# 8                        Warren Resources      NaN      NaN
# 9                                   Xtera      NaN      NaN
# 10                              Mab Group      NaN      NaN
# 11                             McDonald's      NaN      NaN
# 12                     Medical Pharmacies      NaN      NaN
# 13                             APG Neuros      NaN      NaN
# 14                      Thomson Broadbent      NaN      NaN
# 15                                 TUI UK      NaN      NaN
# 16                          InTown Suites      NaN      NaN
# 17                                  Leuze      NaN      NaN
# 18                            Yip in Tsoi      NaN      NaN
# 19                          Hanon Systems      NaN      NaN
# 20                 Overseas Travel Agency      NaN      NaN
# 21                  Volvo Car Corporation      NaN      NaN
# 22                               Arbitech      NaN      NaN
# 23                Skyxe Saskatoon Airport      NaN      NaN
# 24                     Private company #2      NaN      NaN
# 25                      Cadence Aerospace      NaN      NaN
# 26                                 HAPOLO      NaN      NaN
# 27                           ABC Seamless      NaN      NaN
# 29  Since 1985 Premium Transportation Group, Inc. ...  Feb 23, 2022 08:33 PM
# 30  QRS INC. was founded in 1983 to help providers...  Feb 23, 2022 08:31 PM
# 31  CareFirst BlueCross BlueShield Community Healt...  Jan 23, 2022 10:02 PM
# 32  Today, Fittingbox employs more than 80 people ...  Jan 20, 2022 11:09 PM
# 33  SSN_1.csv; PATIENTCONTACTS_VIEW.csv; IB_Appoin...  Jan 16, 2022 09:58 PM
# 34  TaxNetUSA was founded in 1994 and has since be...  Jan 14, 2022 05:06 AM
# 35  Altrux Medical was established in 2006 and is ...  Jan 14, 2022 01:29 AM
# 36  Led by Phillip A. Bock, the attorneys at Bock ...   Jan 8, 2022 09:09 PM
# 37  When Paul Stephens founded Landmark Builders i...   Jan 7, 2022 08:52 PM
# 38  Public Label’s cultural movements’ strategic a...   Jan 6, 2022 08:27 PM
#
#    Post Views
# 0       67095
# 1      128906
# 2      166360
# 3      264558
# 4      160810
# 5      126911
# 6      192516
# 7      125600
# 8      195431
# 9      247429
# 10     276942
# 11     176149
# 12     234424
# 13     233405
# 14     222602
# 15     189660
# 16     157351
# 17     159167
# 18      92487
# 19     150285
# 20      74783
# 21     153064
# 22     147025
# 23     157151
# 24      61568
# 25     140427
# 26      72247
# 27     108124
# 28     113907
# 29      78444
# 30      91410
# 31      95852
# 32      83192
# 33      52161
# 34      47630
# 35      68831
# 36      87862
# 37      87324
# 38      95687

# %% [markdown]
# ## Selenium automation

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %% [markdown]
# ### Searching in Glassdoor

# %%
options = webdriver.ChromeOptions()
options.add_argument('--disable-blink-features=AutomationControlled') 
options.add_argument("enable-automation");
# options.add_argument("--headless");
options.add_argument("--no-sandbox");
options.add_argument("--disable-extensions");
options.add_argument("--dns-prefetch-disable");
options.add_argument("--disable-gpu");

path = 'D:/Downloads/chromedriver'
driver = webdriver.Chrome(options=options, executable_path=path)

for i in range(38, len(df)):
    try:
        company = df['Company Name'][i]
        driver.get('https://www.google.com')
        search = driver.find_element(By.NAME, 'q')
        search.send_keys(company + ' glassdoor "overview"')
        search.send_keys(Keys.RETURN)
        
        # Delay to be able to solve Google captcha
        # if i == 23: time.sleep(20)
        glassdoor_page = driver.find_element_by_tag_name('h3') # clicking the first search result
        glassdoor_page.click()
        
        if "glassdoor" not in driver.current_url:
            print('none')
            continue
        
        pagesource = driver.page_source
        soup = BeautifulSoup(pagesource, 'html.parser')
        company_location = company_industry = '-'
        
        labels = soup.find_all('label')
        for label in labels:
            if label.text == "Headquarters:":
                company_location = label.next_sibling.text
                df['Location'][i] = company_location
            elif (label.text == "Industry:"):
                company_industry = label.next_sibling.text
                df['Industry'][i] = company_industry

        print(f'{i}: {company}, {company_location}, {company_industry}')
        
    except:
        print("none")
    
driver.quit()
# Out:
# 38: Match MG, Mississauga, Canada, Advertising & Public Relations

# %%
df.to_csv('snatch_data.csv')
